# %%
import plotly.graph_objects as go
import pandas as pd

# %%
df = pd.read_excel('applications.xlsx')
df.tail()
# Out:
#    Application  Applied  Ghosted   1st Interview  Rejected  Ghosted  \
# 21           A        1       NaN            1.0       1.0      NaN
# 22           K        1       NaN            1.0       NaN      NaN
# 23           C        1       NaN            1.0       NaN      NaN
# 24          G1        1       NaN            1.0       NaN      1.0
# 25          G2        1       NaN            1.0       NaN      NaN
#
#     Tech Exam  2nd Interview  Offer Declined  No Offer  Job Offer
# 21        NaN            NaN             NaN       NaN        NaN
# 22        1.0            1.0             NaN       1.0        NaN
# 23        NaN            1.0             1.0       NaN        NaN
# 24        NaN            NaN             NaN       NaN        NaN
# 25        1.0            NaN             NaN       NaN        1.0

# %%
df = df.fillna(0)
df = df.drop(columns=['Application'])
df = df.astype('int32')

df.tail()
# Out:
#     Applied  Ghosted   1st Interview  Rejected  Ghosted  Tech Exam  \
# 21        1         0              1         1        0          0
# 22        1         0              1         0        0          1
# 23        1         0              1         0        0          0
# 24        1         0              1         0        1          0
# 25        1         0              1         0        0          1
#
#     2nd Interview  Offer Declined  No Offer  Job Offer
# 21              0               0         0          0
# 22              1               0         1          0
# 23              1               1         0          0
# 24              0               0         0          0
# 25              0               0         0          1

# %%
# # input paths
# df_paths = pd.DataFrame(columns=['Source', 'Target'])

# df_paths.loc[0] = ['Applied', 'Ghosted']
# df_paths.loc[1] = ['Applied', '1st Interview']
# df_paths.loc[2] = ['1st Interview', 'Rejected']
# df_paths.loc[3] = ['1st Interview', 'Tech Exam']
# df_paths.loc[4] = ['1st Interview', '2nd Interview']
# df_paths.loc[5] = ['1st Interview', 'Ghosted']
# df_paths.loc[6] = ['Tech Exam', '2nd Interview']
# df_paths.loc[7] = ['Tech Exam', 'Job Offer']
# df_paths.loc[8] = ['2nd Interview', 'No Offer']
# df_paths.loc[9] = ['2nd Interview', 'Offer Declined']

# %%
import numpy as np
df['Paths'] = None
df['Paths'] = df['Paths'].apply(lambda x: [col for col in df.columns[:-1] if df.any()>0] )

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/2473383864.py in <module>
#       1 import numpy as np
#       2 df['Paths'] = None
# ----> 3 df['Paths'] = df['Paths'].apply(lambda x: [col for col in df.columns[:-1] if df.any()>0] )
#       4
#       5 df
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...
